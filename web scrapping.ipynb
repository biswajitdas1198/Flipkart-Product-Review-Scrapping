# %%
pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask_cors
# Out:
# ...
#
# ...

# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
searchstring = "iphone14"

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + searchstring

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14'

# %%
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartpage = uClient.read()

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartpage , "html.parser")

# %%
https://www.flipkart.com/search?q=/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAY05S0C&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=ec3d7923-70a0-497d-bd0f-03312d3c9fb5.MOBGHWFHSV7GUFWA.SEARCH&ppt=sp&ppn=sp&ssid=r5qzeb274g0000001693415696546&qH=e683ba9749683369
# Out:
#   File "C:\Users\BISWAJIT DAS\AppData\Local\Temp\ipykernel_19488\3096727092.py", line 1
#     https://www.flipkart.com/search?q=/apple-iphone-14-blue-128-gb/p/itmdb77f40da6b6d?pid=MOBGHWFHSV7GUFWA&lid=LSTMOBGHWFHSV7GUFWAY05S0C&marketplace=FLIPKART&q=iphone+14+&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=ec3d7923-70a0-497d-bd0f-03312d3c9fb5.MOBGHWFHSV7GUFWA.SEARCH&ppt=sp&ppn=sp&ssid=r5qzeb274g0000001693415696546&qH=e683ba9749683369
#           ^
# SyntaxError: invalid syntax

# %%
bigboxes = flipkart_html.findAll("div" , {"class": "_1AtVbE col-12-12"})

# %%
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><div><a class="_3WcRHs _2VGJMH" href="/top-deals-from-house-of-apple-8u3ertr64d-store?param=3575233"><div class="_3ywSr_" style="padding-top:25.18%"><div class="_1bEAQy _312yBx" style="padding-top:25.18%"><img alt="A" class="_2OHU_q"/><img alt="A" class="kJjFO0 _3DIhEh" src="https://rukminim2.flixcart.com/fk-p-flap/100/100/image/542895fb50b1914f.png?q=50"/></div></div></a></div></div>,
# ...

# %%
len(bigboxes)
# Out:
# 31

# %%
box = bigboxes[3]

# %%
box.div.div.div
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&amp;lid=LSTMOBGHWFHECFVMDCXSSCYWA&amp;marketplace=FLIPKART&amp;q=iphone14&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=5683c808-c21a-4796-ac67-5d5c3374c63d.MOBGHWFHECFVMDCX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=jjduaaj3mo0000001693487748677&amp;qH=694e31eb1200eb29" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 14 (Midnight, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/9/e/e/-original-imaghx9q5rvcdghy.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span><
# ...

# %%
"https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&amp;lid=LSTMOBGHWFHECFVMDCXSSCYWA&amp;marketplace=FLIPKART&amp;q=iphone14&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=681ba148-ec45-4505-96e3-8a10527e8b00.MOBGHWFHECFVMDCX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=fqych8u5s00000001693422073812&amp;qH=694e31eb1200eb29"
# Out:
# 'https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&amp;lid=LSTMOBGHWFHECFVMDCXSSCYWA&amp;marketplace=FLIPKART&amp;q=iphone14&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=681ba148-ec45-4505-96e3-8a10527e8b00.MOBGHWFHECFVMDCX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=fqych8u5s00000001693422073812&amp;qH=694e31eb1200eb29'

# %%
productlink = "https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-14-midnight-128-gb/p/itm9e6293c322a84?pid=MOBGHWFHECFVMDCX&lid=LSTMOBGHWFHECFVMDCXSSCYWA&marketplace=FLIPKART&q=iphone14&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=5683c808-c21a-4796-ac67-5d5c3374c63d.MOBGHWFHECFVMDCX.SEARCH&ppt=None&ppn=None&ssid=jjduaaj3mo0000001693487748677&qH=694e31eb1200eb29'

# %%
productreq = requests.get(productlink)

# %%
productreq
# Out:
# <Response [200]>

# %%
productreq.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.d4bb4f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
prod_html = bs(productreq.text,"html.parser")

# %%
comment_box = prod_html.find_all("div", {"class" : "_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
for i in comment_box :
    
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19488\2288397629.py in <module>
#       1 for i in comment_box :
#       2
# ----> 3     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[1].div.div
# Out:
# <div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Great product</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Nice camera but battery drain fast specially on video recording</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_aaa2d0a6f1aa47c0875533ff6daf5dd8.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_768f46f3a1404763ab3a23b413a1af82.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_79cf68aae8054d4a923cb2a23590f916.jpeg?q=90), url(
# ...

# %%
comment_box[1].div.div.find_all("div" ,{"class" : ""})[0].div.text
# Out:
# 'Nice camera but battery drain fast specially on video recording'

# %%
for i in comment_box : 
    print(i.div.div.find_all("div" ,{"class" : ""})[0].div.text)
    print("\n")
# Out:
# Good
#
#
# Nice camera but battery drain fast specially on video recording
#
#
# Best smart phone under this price range compare to other phones in 2023 if you see overall build quality, performance and Camera with autofocus and video action mode are awesome50% extra RAM compared to iPhone 13 and other more features. Best time to upgrade to iPhone 14 . I am so happy See Low light photos are amazing..
#
#
# Just amazing!
#
#
# Nice UI and Fast
#
#
# Awesome 👍
#
#
# Ultimate
#
#
# Awesome phone with amazing features
#
#
# Thanku filipkart best phone in the world ❤️
#
#
# Just awesome....❤️🙌😌Display Camera Battery Processor....JUST WOW....✨💗☺️
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19488\4079056597.py in <module>
#       1 for i in comment_box :
# ----> 2     print(i.div.div.find_all("div" ,{"class" : ""})[0].div.text)
# ...

# %%
comment_box[1].div.div.find_all("p" , {"class" : "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Tara singh mehra'

# %%
for i in comment_box:
    print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0].text)
# Out:
# Avi Nash
# Tara singh mehra
# Rahul Prasad
# Ajay Kumar
# Narendar Redyy
# Ashwini  biswal
# Vaish Khan
# Mainak Das
# Shivam  kumar
# Abinash Bhuyan Rajput
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19488\403525825.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p" , {"class" :"_2sc7ZR _2V5EHH" })[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'
